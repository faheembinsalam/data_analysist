# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
total_salary = int(input("Enter Your total salary:" ))
total_years = float(input("Enter your total years for work:"))

if total_years > 5:
    bonus = total_salary * 0.05
    print("Your bonus is:" , bonus)
else:
      print("You are not eligible for a bonus.")
# Out:
# Your bonus is: 2500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age:"))

if age >= 18:
  print("You are eligible to vote.")
else:
  print("You are not eligible to vote.")
# Out:
# You are eligible to vote.

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
user_number = int(input("Enter a Number:"))

if user_number % 2 == 0:
  print(f"The number {user_number}is even.")
else:
  print(f"The number {user_number} is odd.")
# Out:
# The number 7 is odd.

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
div_number = int(input("Enter a number"))

if div_number % 7 == 0:
  print(f"Your number {div_number} is divisible by 7.")
else:
  print(f"Your number {div_number} is not divisible by 7.")
# Out:
# Your number 52 is not divisible by 7.

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
hb_number = int(input("Enter a number:"))

if hb_number % 5 == 0:
  print("Hello")
else:
  print("Bye")
# Out:
# Hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
put_number = int(input("Enter a number:"))

last_digit = put_number % 10
print(f"The last digit of the number {put_number} is {last_digit}.")
# Out:
# The last digit of the number 4500 is 0.

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = int(input("Enter the length :"))
breadth = int(input("Enter the breadth:"))

if length == breadth:
  print(f"The shape Length {length} and Breadth {breadth} is a square.")
else:
  print(f"The shape Length {length} and Breadth {breadth} is a rectangle.")
# Out:
# The shape Length 20 and Breadth 30 is a rectangle.

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
user_one = int(input("Enter a number:"))
user_two = int(input("Enter another number:"))

if user_one > user_two:
  print(f"The number {user_one} is greater than {user_two}.")
elif user_one < user_two:
  print(f"The number {user_one} is less than {user_two}.")
else:
  print(f"The number {user_one} is equal to {user_two}.")
# Out:
# The number 5 is less than 10.

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
quantity = int(input("Enter the quantity of items:"))
unit_price = 100

total_cost = quantity * unit_price
if total_cost > 1000:
  discount = total_cost * 0.01
  total_cost = total_cost - discount
  print(f"Total cost after discount is: {total_cost}")
else:
  print(f"Total cost is: {total_cost}")
# Out:
# Total cost after discount is: 1089.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = int(input("Enter your marks: "))

if marks < 25:
    grade = "F"

elif marks >= 25 and marks < 45:
    grade = "E"

elif marks >= 45 and marks < 50:
    grade = "D"

elif marks >= 50 and marks < 60:
    grade = "C"

elif marks >= 60 and marks <= 80:
    grade = "B"

else:
    grade = "A"

print("Your grade is:", grade)
# Out:
# Your grade is: B

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
classes_held = int(input("Enter number of classes held: "))
classes_attended = int(input("Enter number of classes attended: "))

attendance = (classes_attended / classes_held) * 100

print("Attendance Percentage:", attendance, "%")

if attendance >= 75:
    print("Student is allowed to sit in exam")
else:
    print("Student is not allowed to sit in exam")
# Out:
# Attendance Percentage: 55.55555555555556 %
# Student is not allowed to sit in exam

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
classes_held = int(input("Enter number of classes held: "))
classes_attended = int(input("Enter number of classes attended: "))

medical = input("Do you have medical cause? (Y/N): ")

attendance = (classes_attended / classes_held) * 100

print("Attendance Percentage:", attendance, "%")

if attendance >= 75 or medical == "Y":
    print("Student is allowed to sit in exam")
else:
    print("Student is not allowed to sit in exam")
# Out:
# Attendance Percentage: 55.55555555555556 %
# Student is not allowed to sit in exam

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("Enter a year: "))

if year % 400 == 0:
    print(year, "is a leap year")

elif year % 100 == 0:
    print(year, "is not a leap year")

elif year % 4 == 0:
    print(year, "is a leap year")

else:
    print(year, "is not a leap year")
# Out:
# 2023 is not a leap year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("Enter age: "))

gender = input("Enter gender (M/F): ").upper()

marital = input("Enter marital status (Y/N): ").upper()


if age < 20 or age > 60:
    print("ERROR")

elif gender == "F":
    print("Employee will work only in urban areas")

elif gender == "M":
    if age >= 20 and age <= 40:
        print("Employee may work anywhere")

    elif age > 40 and age <= 60:
        print("Employee will work only in urban areas")

else:
    print("Invalid gender")
# Out:
# Employee may work anywhere

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
units = int(input("Enter number of units: "))

bill = 0

if units <= 100:
    bill = 0

elif units <= 300:
    bill = (units - 100) * 5

else:
    bill = (200 * 5) + ((units - 300) * 10)

print("Total electricity bill is Rs.", bill)
# Out:
# Total electricity bill is Rs. 1500

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1 = int(input("Enter age of first person: "))
age2 = int(input("Enter age of second person: "))
age3 = int(input("Enter age of third person: "))

# Finding oldest
if age1 >= age2 and age1 >= age3:
    oldest = age1

elif age2 >= age1 and age2 >= age3:
    oldest = age2

else:
    oldest = age3


# Finding youngest
if age1 <= age2 and age1 <= age3:
    youngest = age1

elif age2 <= age1 and age2 <= age3:
    youngest = age2

else:
    youngest = age3


print("Oldest person's age is:", oldest)
print("Youngest person's age is:", youngest)
# Out:
# Oldest person's age is: 50
# Youngest person's age is: 20
